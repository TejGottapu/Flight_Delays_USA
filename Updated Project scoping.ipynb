# %% [markdown]
# # Project Title: Analysis of Flights delays in USA
#
#
#    The collection of information we considered as part of dataset talks about the most common information of flights that are delayed in Arrivals & Departures at various states within Americas. The in-scope of the dataset stands defined with a purview of granular information pertaining to scheduled flight journeys.
#
# This data allows us to play around with observations of various types and sub-types of parameters which contribute to delays in Aviation traffic. As an achievable output we aim to arrive at a conclusion of various demographics & Analytical representation of data using Classification models & its interpretation. The selected content of information helps with deep learning in influential factors of managing/better approach of flight traffic, which basis the standards, industry's best practices & that are well defined within the policies of US department of Aviation. While we also aim to provide a summary on the correlation of multiple patterns of flight delays and associated huge revenue loss to Airlines. A further detail on efficiency of flight travel time, Airlines reputation, Safety as a top priority, which results in successful arrivals & departures of flights, as scheduled.

# %% [markdown]
# ====================================================================================================================
#
#     Full Name: Hari Prasad Kotapalli
#     Student ID: 14399416
#     Email ID: hk672@drexel.edu
#
# An engineer by profession with working experience of over 14 years in IT firm, Banking IT infrastructure, Offshore Business Migration, & brings in expertise as IT Technical Document Writer, Human Resources Sr. Professional. Certified in Six Sigma, ITIL, Project Management Professional (PMP). I add up value of Document writing, applying Python programming skills besides logical thinking, highilght key observations & analytical skills applied as my key contribution to this project.
#
#     Full Name: Tej Gottapu
#     Student ID: 14395897
#     Email ID: tg672@drexel.edu
#
# Worked as software Quality Assurance professional with about 4 years of experience in IT firm, having worked on Insurance and Airline domains. Experience in Functional, Regression testing on the front-end application and backend using web services. I would contribute to the Data analysis & visualisation.
#
#
#     Full Name: Sabarnath Maddineni
#     Student ID: 14399443
#     Email ID: scm345@drexel.edu
#
# Has overall working experience of 9 years as an ERP specialist, Cyber security analyst. Would like to contribute towards Data analysis & prediction models in this project accomplishment.
#
#
#     Full Name: Soujanya Navuluru
#     Student ID: 14394436
#     Email ID: sn863@drexel.edu
#
# With an overall 4 years of working experience with IT firm, pertaining to Java programming, Incident Management in Manufacturing & Financial domains. Also, I am a certified professional in Oracle Java-SE. Would like to involve myself with implementation & analytics parts of this project.
#
# ====================================================================================================================

# %% [markdown]
# As efforts of this project accomplishment, a thorough study of flight information, detailed analysis of this dataset & identifying the specific categories which influence the delays are involved. We see this analysis to benefit the Airline players, Aviation authorities to better regulate the Air Traffic & avoid anticipated flight delays.
#
# At this preliminary stage of the Project, we have explored various types of information present in this chosen dataset. A pictorial represenataion of certain parameters when compared with other relevant data is planned to be exhibited in the due course of accomplishments. A snippet of the data collection is below as a reference.

# %%
import pandas as pd
data = pd.read_csv("Flight Delays.csv")
data.head()
# Out:
# C:\Users\npula\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# ...

# %%
data.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
data.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# Below data is a snippet of only the first 100,000 values of overall records captured in the chosen Dataset.

data = data.head(100000)

# %%
## set the figure dimensions
hist_fig = plt.figure(figsize = (6, 6))
    
## make a histogram and set the number of bins to 15
_  = plt.hist(data["DAY_OF_WEEK"], bins = 15)

## Set the tick and label fontsize
plt.tick_params(labelsize = 15)

## Set the title
_ = plt.title("Number of Flight delays Vs Day_of_week", fontsize = 15)

## Set the y-label
_ = plt.ylabel("Number of Flight delays", fontsize = 15)

## Set the y-label
_ = plt.xlabel("DAY_OF_WEEK", fontsize = 15)

#_ = plt.legend(fontsize = 15)

# %%
_  = plt.hist(data["AIRLINE"], bins = 10)

# %%
## set the figure dimensions
scat_fig = plt.figure(figsize = (6, 6))
    
## make a scatter plot
_  = plt.scatter(data["ELAPSED_TIME"],data["AIR_TIME"],color = "black", s = 5, alpha = 0.1)

## Set the tick and label fontsize
plt.tick_params(labelsize = 15)

## Set the title
_ = plt.title("ELAPSED_TIME vs. AIR_TIME", fontsize = 15)

## Set the y-label
_ = plt.ylabel("AIR_TIME", fontsize = 15)

## Set the y-label
_ = plt.xlabel("ELAPSED_TIME", fontsize = 15)

# %% [markdown]
# It is also observed that arbitraries involved in Sales of flight tickets find this analysis useful in better suggesting a passenger/customer for an efficient air-travel, avoiding possible flight delays.
#
# The analysis on this dataset helps with circumstances such as, non-cooperative weather conditions, investigations pertaining to Air Traffic Controlling operations, to an extent of incidents that might occur due to flight delays.
#
# Customer Personalisation, Real time decisioning of flight schedules in offering best possible service to passengers as a probable fit.

# %% [markdown]
# Current analysis limits us from understanding invariable constraints such as flying restrictions, health epidemics, circumstances during political conflicts, natural calamities which demand for flight diversions & cancellations.
#
# Also, unforeseen situations which arise as immediate need while running regular flight operative schedules, including dependencies requiring manual intervention & critical crisis situations are not as part of this existing dataset.

# %% [markdown]
# For a continued analysis of flight schedule delays, the information pertaining to underpinning causes of delayed flight departures, availability of terminals/hanger, failure in ontime departures due to any unavoidable conditions is required to be known.

# %% [markdown]
# The present data considered for this project consists of all the flight delays captured in year 2015, which include:
# "YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, Flight TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, Flight ARRIVAL_TIME, ARRIVAL_DELAY, Flights DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY"
#
# We see the dataset has a combination of variables of different Data-types (Integers, Strings in nature).

# %%
#### Answer to the question asked based on the project scoping submitted :"some columns have large portion of missing data, are you going to use the columns?"

It is observed that on an average of 40-50% of values are available in certain coloumns(with NAN data) of the chosen dataset.As described in the aim of this project we intend to directly not rely on the below listed coloumns, but rather consider these coloumns only further to arriving on the trained model of dataset.

#### The other question asked based on the scopping submitted :"How to interpret the visualization? Like the last scatter plot"
Given the fact that all the airlines had delays in arrival and in departures for every day of the week which made the data representation in the scatter plot a bit ambigious.Further to our efforts made on this point we arrived at an alternative way of representating the information in the below way considering new parameters:
"DEPARTURE_DELAY Vs. ARRIVAL_DELAY"

#### The last question asked against the scoping was :" Further analysis of the data can be more specific"
Of the 5 weeks left for the project implementation below is the week wise break up for the reference: 

Week 1-Understanding the data.
Week 2 -Dataprocessing --Converting the numbers into readable format to be able to classify and determine in the way of our aim of this project.
Week 3- As the data set deals with delays of flights,would like to apply best suitable model for classification.
Week 4 - Tools like Tableu,R,Python to give the efforts made in week 2 - week 4 and give it a proper shape,along with its corresponding documentation.
Week 5- Consolidation of efforts and consultation based on the final draft.
Week 6- Submition of final project.

# %%
scat_fig = plt.figure(figsize = (6, 8))
    
## make a scatter plot
_  = plt.scatter(data["DEPARTURE_DELAY"], data["ARRIVAL_DELAY"],color = "black", s = 5, alpha = 0.1)

## Set the tick and label fontsize
plt.tick_params(labelsize = 15)

## Set the title
_ = plt.title("DEPARTURE_DELAY Vs. ARRIVAL_DELAY", fontsize = 15)

## Set the y-label
_ = plt.ylabel("ARRIVAL_DELAY", fontsize = 15)

## Set the y-label
_ = plt.xlabel("DEPARTURE_DELAY", fontsize = 15)

# %% [markdown]
# Primarily, the data collection was made from trusted source - Web link: https://www.kaggle.com/usdot/flight-delays/
